# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y , yp):
    mse = MSE = sum((y-yp)**2)/len(yp)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 218.528
# The Mean absolute error is 12.265

# %% [markdown]
# TMDB Box Office Prediction
#
# 1. 你選的這組資料為何重要
# 目前單純想要了解，電影營收和狀況是否真的有關聯
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# TMDB
#
# 3. 蒐集而來的資料型態為何
# CSV檔案
#
# 4. 這組資料想解決的問題如何評估
# 想要了解電影營收和製作成本是否有存在甚麼關係，目前還在研究

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績：成本降低，QA為穩，來客提升，營收增加，增加員工功能，提升推播率
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 透過APP取得客戶資料，像是滿意度、價格、是否推薦使用，來評估QA和觀察使用者是否提升
#
# 3. 蒐集而來的資料型態為何
# 資料庫 CSV
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 利用消費心理去支持理論，在小型實驗該策略是否正確
